# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df=pd.read_csv(r"C:\Users\LENOVO\Desktop\internship\model-3\insurance_data.csv")

# %%
df.head(2)
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0

# %%
x=df[["age"]]
y=df.bought_insurance

# %%
plt.title("AGE VS BOUGHT INSURANCE")
plt.xlabel("Age")
plt.ylabel("Bought_Insuranve")
plt.scatter(x,y,color="red")

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
model.predict([[20]])
# Out:
# array([0])

# %%
a=int(input("Enter the value of age: "))
if model.predict([[a]])[0]==0:
    print("person will not buy insurance")
else:
    print("person will buy insurance")
# Out:
# person will not buy insurance

# %%
# spliting the data into training and testing

train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2)

# %%
len(train_x),len(test_x),len(train_y),len(test_y)
# Out:
# (21, 6, 21, 6)

# %%
model=LogisticRegression()

# %%
model.fit(train_x,train_y)
# Out:
# LogisticRegression()

# %%
model.predict(test_x)
# Out:
# array([0, 0, 1, 0, 1, 0])

# %%
test_y
# Out:
# 26    0
# 1     0
# 4     1
# 13    0
# 23    1
# 11    0
# Name: bought_insurance, dtype: int64

# %%
model.score(test_x,test_y)
# Out:
# 1.0

# %%
import pickle

# %%
pickle.dump(model,open("mymodel.pkl","wb"))
